# %%
# !pip3 install opencv-python

# %%
import cv2

# %%
cv2.imread('/home/aabir/Documents/Machine Learning/python/Batman.jpg')
# Out:
# array([[[ 6,  8, 16],
#         [ 7,  9, 17],
#         [ 8, 10, 18],
#         ...,
#         [11, 13, 21],
#         [11, 13, 21],
#         [11, 13, 21]],
#
#        [[ 7,  9, 17],
#         [ 9, 11, 19],
#         [10, 12, 20],
#         ...,
#         [10, 12, 20],
#         [10, 12, 20],
#         [11, 13, 21]],
#
#        [[ 8, 10, 18],
#         [ 9, 11, 19],
#         [10, 12, 20],
#         ...,
#         [ 9, 11, 19],
#         [10, 12, 20],
#         [10, 12, 20]],
#
#        ...,
#
#        [[ 6,  8, 16],
#         [ 5,  7, 15],
#         [ 5,  7, 15],
#         ...,
#         [11, 13, 24],
#         [12, 14, 25],
#         [12, 14, 25]],
#
#        [[ 4,  6, 14],
#         [ 4,  6, 14],
#         [ 4,  6, 14],
#         ...,
#         [11, 13, 24],
#         [11, 13, 24],
#         [12, 14, 25]],
#
#        [[ 3,  5, 13],
#         [ 4,  6, 14],
#         [ 4,  6, 14],
#         ...,
#         [11, 13, 24],
#         [11, 13, 24],
#         [12, 14, 25]]], dtype=uint8)

# %%
img = cv2.imread('/home/aabir/Documents/Machine Learning/python/Batman.jpg') #to read an image

# %%
print(img.shape)
# Out:
# (3648, 5472, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #display the image

# %%
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #converting images
gray_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(rgb_image)
plt.axis('off') #not displaying the axis of the graph
# Out:
# (-0.5, 5471.5, 3647.5, -0.5)

# %%
plt.imshow(gray_image)

# %%
crop_image = img[1000:3000,2500:5000,:] #cropping the image
plt.imshow(crop_image)
plt.axis('off')
plt.show()

# %%
crop_image.shape
# Out:
# (2000, 2500, 3)

# %%
img.resize?

# %%
crop_img = cv2.resize(crop_image,(100,100))
plt.imshow(crop_img)
plt.axis('Off')
plt.title('Bat'+str(crop_img.shape))
plt.show()
